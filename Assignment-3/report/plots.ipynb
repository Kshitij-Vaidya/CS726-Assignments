# %%
import numpy as np
import matplotlib.pyplot as plt

# Data
methods = [
    "Greedy", "Random (τ=0.5)", "Random (τ=0.9)",
    "Top-k (k=5)", "Top-k (k=10)", "Nucleus (p=0.9)"
]
bleu_scores = [0.3099, 0.2928, 0.1985, 0.2476, 0.2490, 0.0846]
rouge_1_scores = [0.3543, 0.2932, 0.2000, 0.2464, 0.2584, 0.1473]
rouge_2_scores = [0.1296, 0.0931, 0.0585, 0.0698, 0.0797, 0.0422]
rouge_lcs_scores = [0.2710, 0.2266, 0.1647, 0.1826, 0.1984, 0.1153]

x = np.arange(len(methods))  # X-axis positions
width = 0.2  # Width of bars

# Plot BLEU scores
plt.figure(figsize=(12, 6))
plt.bar(x - 1.5 * width, bleu_scores, width, label="BLEU", color='b')
plt.bar(x - 0.5 * width, rouge_1_scores, width, label="ROUGE-1", color='g')
plt.bar(x + 0.5 * width, rouge_2_scores, width, label="ROUGE-2", color='r')
plt.bar(x + 1.5 * width, rouge_lcs_scores, width, label="ROUGE-LCS", color='y')

plt.xlabel("Decoding Methods")
plt.ylabel("Scores")
plt.title("Comparison of Decoding Methods")
plt.xticks(x, methods, rotation=20, ha='right')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.savefig("decoding_methods.png")
# Show plot
plt.show()

# %%
metrics = ["BLEU", "ROUGE-1", "ROUGE-2", "ROUGE-LCS"]
scores = [0.19298, 0.43248, 0.27158, 0.39884]

# Plot
plt.figure(figsize=(8, 5))
plt.bar(metrics, scores, color=['b', 'g', 'r', 'y'])

# Labels and title
plt.xlabel("Metrics")
plt.ylabel("Scores")
plt.title("Task 1 - BLEU and ROUGE Scores")
plt.ylim(0, 0.5)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show plot
plt.savefig("task1.png")
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
metrics = ["BLEU", "ROUGE-1", "ROUGE-2", "ROUGE-LCS", "RTF"]
values = [0.2881, 0.3994, 0.1471, 0.3166, 0.1059]

# Plot
plt.figure(figsize=(8, 5))
plt.bar(metrics, values, color=['blue', 'green', 'red', 'purple', 'orange'])
plt.xlabel("Metrics")
plt.ylabel("Scores")
plt.title("Evaluation Metrics")
plt.ylim(0, 0.5)

# Display values on bars
for i, v in enumerate(values):
    plt.text(i, v + 0.02, str(round(v, 4)), ha='center')
    plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.savefig("task2_single.png")
plt.show()

# %%
# Multi Head (W=2, S=2) & 0.2091 & 0.3213 & 0.0898 & 0.2530 & 0.1944 \\
# Multi Head (W=2, S=5) & 0.2564 & 0.3700 & 0.1283 & 0.2958 & 0.2615 \\
# Multi Head (W=5, S=2) & 0.1593 & 0.2811 & 0.0652 & 0.2161 & 0.3711 \\
# Multi Head (W=5, S=5) & 0.2150 & 0.3461 & 0.1083 & 0.2783 & 0.3141 \\
# Multi Head (W=10, S=2) & 0.1041 & 0.2305 & 0.0645 & 0.1912 & 0.8776 \\
#         Multi Head (W=10, S=5) & 0.1655 & 0.3069 & 0.1012 & 0.2499 & 0.6389 \\
import numpy as np
import matplotlib.pyplot as plt
# Data
methods = ["(W=2, S=2)", "(W=2, S=5)", "(W=5, S=2)", "(W=5, S=5)", "(W=10, S=2)", "(W=10, S=5)"]
bleu_scores = [0.2091, 0.2564, 0.1593, 0.2150, 0.1041, 0.1655]
rouge_1_scores = [0.3213, 0.3700, 0.2811, 0.3461, 0.2305, 0.3069]
rouge_2_scores = [0.0898, 0.1283, 0.0652, 0.1083, 0.0645, 0.1012]
rouge_lcs_scores = [0.2530, 0.2958, 0.2161, 0.2783, 0.1912, 0.2499]
rtf_scores = [0.1944, 0.2615, 0.3711, 0.3141, 0.8776, 0.6389]

x = np.arange(len(methods))  # X-axis positions
width = 0.1  # Width of bars

# Plot BLEU scores
plt.figure(figsize=(12, 6))
plt.bar(x - 2 * width, bleu_scores, width, label="BLEU", color='b')
plt.bar(x - width, rouge_1_scores, width, label="ROUGE-1", color='g')
plt.bar(x, rouge_2_scores, width, label="ROUGE-2", color='r')
plt.bar(x + width, rouge_lcs_scores, width, label="ROUGE-LCS", color='y')
plt.bar(x + 2 * width, rtf_scores, width, label="RTF", color='purple')

plt.xlabel("Decoding Methods")
plt.ylabel("Scores")
plt.title("Comparison of Decoding Methods")
plt.xticks(x, methods, rotation=0, ha='center')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.savefig("task2_multi.png")
# Show plot
plt.show()
