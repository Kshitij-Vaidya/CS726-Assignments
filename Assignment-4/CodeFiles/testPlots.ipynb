# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
samplePath = '/home/sedrica/CS726-Assignments/Assignment-4/DataFiles/OutputAlgo1.pt'
sampleData = torch.load(samplePath)
print(sampleData.shape)
# Out:
# torch.Size([900, 16, 784])

# %%
samples = sampleData.reshape(-1, sampleData.shape[-1]) 
print(samples.shape)
# Out:
# torch.Size([14400, 784])

# %%
tsne = TSNE(n_components=2, perplexity=30, learning_rate='auto', init='random', random_state=42)
embedded = tsne.fit_transform(samples.cpu().numpy())

# %%
plt.figure(figsize=(8, 6))
plt.scatter(embedded[:, 0], embedded[:, 1], s=5, alpha=0.6)
plt.title("t-SNE Projection of Algo1 Samples in 2D")
plt.xlabel("Component 1")
plt.ylabel("Component 2")
plt.grid(True)
plt.show()

# %%
testDataPath = '/home/sedrica/CS726-Assignments/Assignment-4/DataFiles/A4_test_data.pt'
testData = torch.load(testDataPath)
# tests = testData['energy'].reshape(-1, testData['energy'].shape[-1])
tests = testData['energy'].reshape(testData['energy'].shape[0], -1)
tests = tests[::100]
print(tests.shape)

tsne = TSNE(n_components=2, perplexity=30, learning_rate='auto', init='random', random_state=42)
embeddedTest = tsne.fit_transform(tests.cpu().numpy())

plt.figure(figsize=(8, 6))
plt.scatter(embeddedTest[:, 0], embeddedTest[:, 1], s=5, alpha=0.6)
plt.title("t-SNE Projection of Algo1 Samples in 2D")
plt.xlabel("Component 1")
plt.ylabel("Component 2")
plt.grid(True)
plt.show()
# Out:
# torch.Size([1000, 1])
